# %%
# MODULES
import pandas as pd

# %%
# READ INPUT FILES
flightsDF = pd.read_csv('Filghts TEC_Valid.csv')
salesDF = pd.read_csv('Sales TEC_Valid.csv')

flightsDF, salesDF
# Out:
# (                               Flight_ID Aeronave DepartureStation  \
#  0       ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
#  1       efd86c996035dacdca7a0ccb2560dda1   XA-VIX               BM
#  2       6cfa1bbaa44f08fc7d3061f034a6a5ce   XA-VBV               AW
#  3       dd0fad3248951d2f71d63e6279aeaa4b   XA-VBW               AW
#  4       d0987ee648eea254063bfe2b39571b67   XA-VAP               BA
#  ...                                  ...      ...              ...
#  245748  cc7c1c5e6fd132fd0bdab3a35aac33c0   XA-VBK               BM
#  245749  ef32da2731db80faa8b9f5030979a016   9H-MLV               AW
#  245750  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
#  245751  3c15779202b13158f78e8a8afe377250      NaN               AW
#  245752  20304ab7212bbbe6c77cdc852d4f8d19      NaN               BA
#
#         ArrivalStation     Destination_Type        Origin_Type  \
#  0                  AZ    Ciudad Fronteriza   Ciudad Principal
# ...

# %%
# DESCRIPTION INFO
flightsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245753 entries, 0 to 245752
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Flight_ID         245753 non-null  object
#  1   Aeronave          165363 non-null  object
#  2   DepartureStation  245752 non-null  object
#  3   ArrivalStation    245752 non-null  object
#  4   Destination_Type  245752 non-null  object
#  5   Origin_Type       245752 non-null  object
#  6   STD               245753 non-null  object
#  7   STA               245753 non-null  object
#  8   Capacity          245753 non-null  int64
#  9   Passengers        122228 non-null  float64
#  10  Bookings          122228 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 20.6+ MB

# %%
salesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2564361 entries, 0 to 2564360
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Flight_ID    object
#  1   ProductType  object
#  2   ProductName  object
#  3   Quantity     int64
#  4   TotalSales   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 97.8+ MB

# %%
print(flightsDF.nunique())
print(salesDF.nunique())
# Out:
# Flight_ID           238055
# Aeronave               104
# DepartureStation        41
# ArrivalStation          41
# Destination_Type         5
# Origin_Type              5
# STD                 124769
# STA                 130620
# Capacity                 7
# Passengers             262
# Bookings               218
# dtype: int64
# Flight_ID      108964
# ProductType        21
# ProductName       222
# Quantity           74
# TotalSales       1106
# dtype: int64

# %%
merged_df = flightsDF.merge(salesDF, on='Flight_ID')
merged_df
# Out:
#                                 Flight_ID Aeronave DepartureStation  \
# 0        ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# 1        ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# 2        ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# 3        ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# 4        ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# ...                                   ...      ...              ...
# 2559903  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
# 2559904  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
# 2559905  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
# 2559906  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
# 2559907  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
#
#         ArrivalStation   Destination_Type       Origin_Type  \
# 0                   AZ  Ciudad Fronteriza  Ciudad Principal
# ...

# %%
print(merged_df.nunique())
# Out:
# Flight_ID           104389
# Aeronave                84
# DepartureStation        39
# ArrivalStation          38
# Destination_Type         5
# Origin_Type              5
# STD                  57547
# STA                  60892
# Capacity                 7
# Passengers             251
# Bookings               212
# ProductType             21
# ProductName            221
# Quantity                74
# TotalSales            1092
# dtype: int64
